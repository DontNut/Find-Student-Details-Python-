# %%
import pandas as pd

# %%
df = pd.read_csv(r'/tmp/Students data.csv')
df.head(10)
# Out:
#    StudentID Class  Gender    GPA Accounting Machine Learning Graduate
# 0          1     A    Male  73.47          A                A        N
# 1          2     A  Female  71.22          A                A        N
# 2          3     A  Female  74.56          A                A        Y
# 3          4     A  Female  72.89          A                A        N
# 4          5     A  Female  70.11          A                A        N
# 5          6     A    Male  65.04          B                C        N
# 6          7     A    Male  77.11          A                A        Y
# 7          8     A  Female  64.75          B                C        N
# 8          9     B  Female  77.92          B                A        N
# 9         10     A  Female  76.50          B                A        N

# %%
df.set_index('Graduate',inplace=True)

# %%
df.loc['Y'] # Find All the Students who are Graduates
# Out:
#           StudentID Class  Gender    GPA Accounting Machine Learning
# Graduate
# Y                 3     A  Female  74.56          A                A
# Y                 7     A    Male  77.11          A                A
# Y                14     A    Male  80.08          B                A
# Y                15     A    Male  81.67          A                A
# Y                16     B  Female  82.07          B                A
# Y                17     A    Male  74.11          B                A
# Y                20     A    Male  76.46          B                B
# Y                21     B    Male  75.57          B                A
# Y                30     A  Female  85.29          A                A
# Y                36     A  Female  85.55          A                A
# Y                40     A  Female  84.01          B                A
# Y                42     B  Female  90.66          B                A
# ...

# %%
df.iloc[0] # Find the personal details
# Out:
# StudentID               1
# Class                   A
# Gender               Male
# GPA                 73.47
# Accounting              A
# Machine Learning        A
# Name: N, dtype: object
